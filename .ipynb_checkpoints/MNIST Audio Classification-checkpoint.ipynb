# %% [markdown]
# ### An Audio Version of MNIST Dataset

# %%
import numpy as np
import IPython.display as i_dis
import os
import librosa
import librosa.display as display
import matplotlib.pyplot as plt
import tqdm

# %matplotlib inline
import matplotlib as mlp
import matplotlib.pyplot as plt
mlp.rc("xtick",labelsize=12)
mlp.rc("ytick",labelsize=12)
mlp.rc("axes",labelsize=14)

plt.rcParams['figure.figsize'] = [10,5]
plt.rcParams['figure.dpi'] = 300



import tensorflow as tf
import sklearn
import tensorflow.keras as keras
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedShuffleSplit

MAIN_DIR = "/home/deadpool/github/MNIST-AUDIO-CLASSIFICATION/"
DATA_DIR = os.path.join(MAIN_DIR,"mnist spoken data","recordings")
SAMPLE_DIR = os.path.join(MAIN_DIR,"samples")
LABELS = ["ZERO","ONE","TWO","THREE","FOUR","FIVE","SIX","SEVEN","EIGHT","NINE"]
LENGTH = 9000
SAMPLE_RATE = 8000 #Hz
# os.makedirs("Figures",exist_ok=True)
# FIG_DIR = os.path.join(MAIN_DIR,"Figures")
# print(MAIN_DIR)

# %%
os.chdir(DATA_DIR)
print("Play a sample wavfile from the datset:")
i_dis.Audio("0_theo_4.wav")
# Out:
# Play a sample wavfile from the datset:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Prepare Dataset

# %%
def fetch_data(length=LENGTH):
    audio = []
    labels = []
    for file in os.listdir():
        
        a, SR = librosa.load(file,sr=None)
        a, index = librosa.effects.trim(a,top_db=20,frame_length=256, hop_length=64)
        if(len(a)>length or len(a)<2000):
            continue
        elif(len(a)<length):
            a = np.pad(a,(0,length-len(a)),constant_values=(0,0))
        audio.append(a)
        labels.append(file[0])
    return audio,SR,labels

# %%
audios, SR, labels = fetch_data(length=4000)

# %%
sample_len = [len(x) for x in audios]

# %%
print(SR)
print(len(audios))
# Out:
# 8000
# 1228

# %%
plt.hist(sample_len)
plt.show()

# %%
np.percentile(sample_len,91)
# Out:
# 4000.0

# %%
# librosa.display.waveplot(audios[0],sr=SR)
plt.figure(figsize=(10,4))
plt.title(labels[0])
plt.plot(audios[1000])
plt.grid("ON")
plt.show()

# %%
mfcc = librosa.feature.mfcc(audios[0],sr=SR,n_mfcc=15,hop_length=125,n_fft=512)

# %%
fig, ax = plt.subplots()
img = display.specshow(mfcc, x_axis='time', ax=ax)
# fig.colorbar(img, ax=ax)
ax.set(title='MFCC')
# Out:
# [Text(0.5, 1.0, 'MFCC')]

# %%
mfcc.shape
# Out:
# (15, 33)

# %%
import pandas as pd

# %%
data = pd.Series(labels)

# %%
plt.figure(figsize=(10,8))
data.value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# ### Data Augmentation

# %% [markdown]
# ### NOISE ADDITION

# %%
def add_noise(data, FACTOR=0.003):
    noise = np.random.randn(len(data))
    new_data = data + FACTOR * noise
    return new_data.astype(type(data[0]))

# %%
new_audios_noise = np.array(list(map(add_noise,audios)))

# %%
plt.figure(figsize=(12,5))
plt.plot(audios[0])
plt.plot(new_audios_noise[0],alpha=0.4)
plt.show()

# %%
# original audio
i_dis.Audio(audios[0],rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# manipulated audio
i_dis.Audio(new_audios_noise[0],rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### TIME SHIFTING

# %%
def time_shift(data,SHIFT_LEN=300,SHIFT_DIR ="RIGHT"):
    if SHIFT_DIR != "RIGHT":
        SHIFT_LEN = - SHIFT_LEN
    shifted_data = np.roll(data,SHIFT_LEN)
    if SHIFT_LEN>0:
        shifted_data[:SHIFT_LEN] = 0
    else:
        shifted_data[SHIFT_LEN:] = 0
    return shifted_data

# %%
new_audios_shifted = np.array(list(map(lambda x: time_shift(x,SHIFT_DIR="LEFT"),audios)))

# %%
plt.plot(new_audios_shifted[0])
plt.plot(audios[0],alpha=0.7)
plt.show()

# %%
# original audio
i_dis.Audio(audios[0],rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# original audio
i_dis.Audio(new_audios_shifted[0],rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### CHANGING PITCH

# %%
def change_pitch(data,sr=8000,FACTOR=0.1):
    return librosa.effects.pitch_shift(data,SR,FACTOR)

# %%
new_audios_pitch = np.array(list(map(change_pitch,audios)))

# %% [markdown]
# plt.plot(new_audios_pitch[0])
# plt.plot(audios[0],alpha=0.7)
# plt.show()

# %%
# original audio
i_dis.Audio(audios[0],rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# manipulated audio
i_dis.Audio(new_audios_pitch[0],rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### CHANGING SPEED

# %%
def change_speed(data,RATE=0.5):
    """
    change speed of the given sample
    if rate < 0 --> audio becomes slower
    if rate > 0 --> audio becomes faster
    """
    return librosa.effects.time_stretch(data,RATE)

# %%
new_audios_speed = np.array(list(map(change_speed,audios)))

# %%
plt.plot(new_audios_speed[0])
plt.plot(audios[0],alpha=0.7)
plt.show()

# %%
# original audio
i_dis.Audio(audios[0],rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# manipulated audio
i_dis.Audio(new_audios_speed[0],rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len(new_audios_speed[0])
# Out:
# 8000

# %% [markdown]
# ### Extract Features

# %%
def extract_MFCC(audio,SR,n_mfcc=20,hop_length=125,n_fft=256):
    features = []
    for a,index in zip(audio,tqdm.tqdm( range(len(audio)),desc="Extracting Features: ")):
        mfcc = librosa.feature.mfcc(a,sr=SR,n_mfcc=n_mfcc,hop_length=hop_length,n_fft=n_fft)
        features.append(mfcc.T)
    return features

# %%
features = extract_MFCC(audios,SR)
# Out:
# Extracting Features: 100%|█████████▉| 1227/1228 [00:08<00:00, 148.39it/s]

# %%
encoder = LabelEncoder()
encoded_labels = encoder.fit_transform(labels).astype('float64')

# %%
X = np.array(features)
Y = encoded_labels

# %%
splitter = StratifiedShuffleSplit(n_splits=1,test_size=0.1, random_state=42)

train_id, test_id = next(splitter.split(X,Y))
X_train,y_train,X_test,y_test = X[train_id],Y[train_id],X[test_id],Y[test_id]

train_id, test_id = next(splitter.split(X_train,y_train))
X_train,y_train,X_val,y_val = X_train[train_id],y_train[train_id],X_train[test_id],y_train[test_id]

# %%
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]
X_val = X_val[..., np.newaxis]

INPUT_SHAPE = (X_train.shape[1], X_train.shape[2], 1)

# %%
print(X_train[0].shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (33, 20, 1)
# (994, 33, 20, 1)
# (123, 33, 20, 1)

# %%
model = keras.models.Sequential()
model.add(keras.layers.Conv2D(64,(3,3),activation="sigmoid",input_shape=INPUT_SHAPE,kernel_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D((3, 3), strides=(2,2), padding='same'))

model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu',
                                 kernel_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D((3, 3), strides=(2,2), padding='same'))

# 3rd conv layer
model.add(tf.keras.layers.Conv2D(32, (2, 2), activation='relu',
                                 kernel_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.MaxPooling2D((2, 2), strides=(2,2), padding='same'))

# flatten output and feed into dense layer
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(64, activation='relu'))
tf.keras.layers.Dropout(0.3)

# softmax output layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer="Adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 31, 18, 64)        640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 31, 18, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 9, 64)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 7, 32)         18464
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 7, 32)         128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 4, 32)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 6, 3, 32)          4128
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 6, 3, 32)          128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 3, 2, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 192)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                12352
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 36,746
# Trainable params: 36,490
# Non-trainable params: 256
# _________________________________________________________________

# %%
earlystop_callback = tf.keras.callbacks.EarlyStopping(monitor="accuracy", min_delta=0.001, patience=5)

# %%
history = model.fit(X_train,y_train,epochs=30,batch_size=30,validation_data=(X_val,y_val),callbacks=[earlystop_callback])
# Out:
# Epoch 1/30
# 34/34 [==============================] - 2s 47ms/step - loss: 1.7963 - accuracy: 0.4487 - val_loss: 2.1153 - val_accuracy: 0.3784
# Epoch 2/30
# 34/34 [==============================] - 1s 38ms/step - loss: 0.7549 - accuracy: 0.8189 - val_loss: 1.1055 - val_accuracy: 0.6216
# Epoch 3/30
# 34/34 [==============================] - 1s 41ms/step - loss: 0.3707 - accuracy: 0.9406 - val_loss: 0.4748 - val_accuracy: 0.8829
# Epoch 4/30
# 34/34 [==============================] - 1s 38ms/step - loss: 0.2339 - accuracy: 0.9718 - val_loss: 0.3906 - val_accuracy: 0.9279
# Epoch 5/30
# 34/34 [==============================] - 1s 38ms/step - loss: 0.2005 - accuracy: 0.9759 - val_loss: 0.3122 - val_accuracy: 0.9279
# Epoch 6/30
# 34/34 [==============================] - 1s 43ms/step - loss: 0.1904 - accuracy: 0.9738 - val_loss: 0.2819 - val_accuracy: 0.9189
# Epoch 7/30
# 34/34 [==============================] - 1s 41ms/step - loss: 0.1262 - accuracy: 0.9940 - val_loss: 0.2574 - val_accuracy: 0.9279
# Epoch 8/30
# 34/34 [==============================] - 1s 40ms/step - loss: 0.1065 - accuracy: 0.9990 - val_loss: 0.2569 - val_accuracy: 0.9550
# Epoch 9/30
# 34/34 [==============================] - 2s 44ms/step - loss: 0.0958 - accuracy: 0.9990 - val_loss: 0.2617 - val_accuracy: 0.9369
# Epoch 10/30
# 34/34 [==============================] - 1s 41ms/step - loss: 0.0875 - accuracy: 1.0000 - val_loss: 0.2143 - val_accuracy: 0.9369
# Epoch 11/30
# 34/34 [==============================] - 1s 40ms/step - loss: 0.0826 - accuracy: 1.0000 - val_loss: 0.2031 - val_accuracy: 0.9459
# Epoch 12/30
# 34/34 [==============================] - 1s 39ms/step - loss: 0.0833 - accuracy: 1.0000 - val_loss: 0.2205 - val_accuracy: 0.9369
# Epoch 13/30
# 34/34 [==============================] - 1s 40ms/step - loss: 0.0798 - accuracy: 1.0000 - val_loss: 0.1769 - val_accuracy: 0.9640
# Epoch 14/30
# 34/34 [==============================] - 1s 40ms/step - loss: 0.0767 - accuracy: 1.0000 - val_loss: 0.1869 - val_accuracy: 0.9459
# Epoch 15/30
# 34/34 [==============================] - 1s 39ms/step - loss: 0.0756 - accuracy: 1.0000 - val_loss: 0.1808 - val_accuracy: 0.9640

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print("\nTest loss: {}, test accuracy: {}".format(test_loss, 100*test_acc))
# Out:
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1261 - accuracy: 0.9837
#
# Test loss: 0.12612292170524597, test accuracy: 98.37398529052734

# %%
os.chdir(SAMPLE_DIR)

# %%
i_dis.Audio("0_rabin_0.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample,gan = librosa.load("0_rabin_0.wav",sr=None)

# %%
len(sample)
# Out:
# 11762

# %%
plt.figure(figsize=(10,4))
plt.plot(sample)
plt.grid("ON")
plt.show()

# %%
plt.figure(figsize=(10,4))
off = int(len(sample)/2)
# sample =sample[:4000]
plt.plot(trimmed[:4000])
plt.grid("ON")
plt.show()

# %%
trimmed, index = librosa.effects.trim(sample,top_db=10,frame_length=256, hop_length=64)

# %%
plt.figure(figsize=(10,4))
plt.plot(trimmed)
plt.grid("ON")
plt.show()

# %%
len(trimmed)

# %%
index

# %%
mfcc = librosa.feature.mfcc(sample[:4000],sr=gan,n_mfcc=13,hop_length=256,n_fft=2048)

# %%
mfcc.shape

# %%
mfcc = mfcc[...,np.newaxis]

# %%
mfcc = mfcc[np.newaxis,...]

# %%
mfcc.shape

# %%
model.predict_classes(mfcc)

# %%
real_data = []
real_labels = []
LENGTH = 4000
THRESHOLD = 2000

for file in os.listdir():
    sample,sr = librosa.load(file,sr=None)
    sample, index = librosa.effects.trim(sample,top_db=15,frame_length=256, hop_length=64)
    if(len(sample)>LENGTH):
        sample = sample[:LENGTH]
    if(len(sample)<THRESHOLD):
        print("Corrupt file")
        continue
    if(len(sample)<LENGTH):
        sample = np.pad(sample,(0,LENGTH-len(sample)),constant_values=(0,0))
    mfcc = librosa.feature.mfcc(sample,sr=sr,n_mfcc=20,hop_length=125,n_fft=256)
    real_data.append(mfcc.T)
    real_labels.append(float(file[0]))
    mfcc = mfcc.T[np.newaxis,...,np.newaxis]
    p = model.predict_classes(mfcc)
    print(int(p), end="   ")
    print(file[0])

print(len(real_data))
print(type(real_data))

real_data =np.array(real_data)
real_labels = np.array(real_labels)
real_data = real_data[...,np.newaxis]
model.evaluate(real_data,real_labels)
# Out:
# 3   0
# 7   9
# 3   6
# 7   7
# Corrupt file
# 3   3
# 7   7
# 7   0
# 1   1
# Corrupt file
# 3   3
# Corrupt file
# 3   6
# 3   8
# Corrupt file
# 7   5
# 3   5
# 9   9
# 1   1
# 3   5
# Corrupt file
# Corrupt file
# 3   6
# 3   9
# 9   0
# 7   7
# Corrupt file
# 9   4
# 3   3
# 1   1
# 23
# <class 'list'>
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6029 - accuracy: 0.4348
# [2.6029393672943115, 0.43478259444236755]

# %%
os.listdir()
# Out:
# ['2_theo_37.wav',
#  '0_jackson_25.wav',
#  '1_yweweler_5.wav',
#  '2_theo_38.wav',
#  '0_nicolas_26.wav',
#  '2_theo_36.wav',
#  '1_nicolas_30.wav',
#  '0_nicolas_25.wav',
#  '1_yweweler_8.wav',
#  '0_jackson_26.wav',
#  '0_jackson_27.wav',
#  '1_yweweler_6.wav',
#  '1_nicolas_31.wav',
#  '1_yweweler_7.wav',
#  '0_jackson_28.wav']

# %%
print(real_labels)
# Out:
# [2. 0. 1. 2. 0. 2. 1. 0. 1. 0. 0. 1. 1. 1. 0.]

# %%
model.predict_classes(real_data)
# Out:
# array([2, 0, 1, 2, 0, 2, 1, 0, 1, 0, 0, 1, 1, 5, 0])

# %%
model.predict_classes(real_data[0][np.newaxis,...])
# Out:
# array([2])

# %%
real_data[0].shape
# Out:
# (33, 20, 1)
